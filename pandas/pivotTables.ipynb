# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    729     97   John  January      Q1
# 1  2023-01-02       B   West    366     88   Mary  January      Q1
# 2  2023-01-03       C  North    822     80    Bob  January      Q1
# 3  2023-01-04       D  South    846     24  Alice  January      Q1
# 4  2023-01-05       A   East    307     90   John  January      Q1
# 5  2023-01-06       B   West    411     74   Mary  January      Q1
# 6  2023-01-07       C  North    459     57    Bob  January      Q1
# 7  2023-01-08       D  South    862     56  Alice  January      Q1
# 8  2023-01-09       A   East    396     39   John  January      Q1
# 9  2023-01-10       B   West    583     92   Mary  January      Q1
# 10 2023-01-11       C  North    242     15    Bob  January      Q1
# 11 2023-01-12       D  South    770     85  Alice  January      Q1
# 12 2023-01-13       A   East    664     40   John  January      Q1
# 13 2023-01-14       B   West    886     34   Mary  January      Q1
# 14 2023-01-15       C  North    905     83    Bob  January      Q1
# 15 2023-01-16       D  South    899     88  Alice  January      Q1
# 16 2023-01-17       A   East    538     62   John  January      Q1
# 17 2023-01-18       B   West    753     29   Mary  January      Q1
# 18 2023-01-19       C  North    579     77    Bob  January      Q1
# 19 2023-01-20       D  South    134     41  Alice  January      Q1

# %%
# it is used for aggregation
pd.pivot_table(df, values="Sales", index="Region", columns="Product", aggfunc="mean")
# Out:
# Product      A      B      C      D
# Region
# East     526.8    NaN    NaN    NaN
# North      NaN    NaN  601.4    NaN
# South      NaN    NaN    NaN  702.2
# West       NaN  599.8    NaN    NaN

# %%
pd.pivot_table(df, values="Sales", index="Region", columns="Product", aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     538.0    NaN    NaN    NaN
# North      NaN    NaN  579.0    NaN
# South      NaN    NaN    NaN  846.0
# West       NaN  583.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     526.8    NaN    NaN    NaN  65.6   NaN   NaN   NaN
# North      NaN    NaN  601.4    NaN   NaN   NaN  62.4   NaN
# South      NaN    NaN    NaN  702.2   NaN   NaN   NaN  58.8
# West       NaN  599.8    NaN    NaN   NaN  63.4   NaN   NaN

# %% [markdown]
# ### cross tables

# %%
pd.crosstab(df["Region"], df["Product"]) # it used for counting purpose
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
